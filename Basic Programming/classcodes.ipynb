# %%
a=5
print(type(a))
# Out:
# <class 'int'>

# %%
a=10
print(a)
# Out:
# 10

# %%
a=9.6
a=9.4
print(a)
# Out:
# 9.4

# %%
arr=[10]
print(type(arr))
# Out:
# <class 'list'>

# %%
arr.append(20)
print(arr)
# Out:
# [10, 20]

# %%
arr.append(30)

# %%
arr
# Out:
# [10, 20, 30]

# %%
s="gaurav"
print(len(s))
# Out:
# 6

# %% [markdown]
# ## sum of n natural numbers

# %% [raw]
# n=5
# 1+2+3+4+5=15
# n=10
# 1+2+3+....10=55

# %%
def sum_Natural(n):
    sum=0
    for i in range(1,n+1,1):
        sum=sum+i
    return sum
n=int(input())
print(sum_Natural(n))
# Out:
#  100000000
# 5000000050000000

# %%
n=int(input())
print(n*(n+1)//2)
# Out:
#  3478145781413123
# 6048749038380953739142289013126

# %%
n=int(input())
count=0
for i in range(0,n,1):
    count=count+1
print(count)
# Out:
#  100000000
# 100000000

# %%
n=int(input())
count=0
for i in range(0,n,1):
    for j in range(0,n,1):
        count=count+1
print(count)
# Out:
#  10
# 100

# %%
n=int(input())
count=0
for i in range(0,n,1):
    for j in range(0,n,1):
        for k in range(0,n,1):
            count=count+1
print(count)
# Out:
#  1000
# 1000000000
